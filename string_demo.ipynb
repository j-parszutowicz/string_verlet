# %% [markdown]
# <a href="https://colab.research.google.com/github/j-parszutowicz/string_verlet/blob/main/string_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ string_verlet
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# Collecting string_verlet
#   Downloading https://test-files.pythonhosted.org/packages/e2/c5/1ca6ff6064487a9b26548b0ded8799e2eea522ee4da6c3ed5d0fa065dd24/string_verlet-0.1.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from string_verlet) (2.0.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from string_verlet) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->string_verlet) (0.43.0)
# Downloading https://test-files.pythonhosted.org/packages/e2/c5/1ca6ff6064487a9b26548b0ded8799e2eea522ee4da6c3ed5d0fa065dd24/string_verlet-0.1.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: string_verlet
# Successfully installed string_verlet-0.1.0

# %%
import numpy as np
from matplotlib import pyplot as plt
from string_verlet import Verlet

initial_condition = lambda x: np.exp(-100 * (x - 0.5) ** 2)

X, T, Z = Verlet(n=101, dx=0.01, dt=0.005, t_max=5.0, f0=initial_condition)

X_grid, T_grid = np.meshgrid(X, T)

# 3D
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X_grid, T_grid, Z, cmap='viridis')
ax.set_title('3D Surface')
ax.set_xlabel('Position (x)')
ax.set_ylabel('Time (t)')
ax.set_zlabel('Displacement (u)')
plt.show()

# 2D Heatmap
plt.figure(figsize=(8, 5))
plt.pcolormesh(X_grid, T_grid, Z, cmap='viridis', shading='auto')
plt.colorbar(label='Displacement ($u$)')
plt.title('Heatmap')
plt.xlabel('Position ($x$)')
plt.ylabel('Time ($t$)')
plt.show()
